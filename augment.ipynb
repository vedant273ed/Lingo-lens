# %%
import os
import cv2
import random
from tqdm import tqdm

# Paths
source_dataset = r"E:\New folder\isl_dataset-cropped"  # Your cropped dataset
target_dataset = r"E:\New folder\isl_inverted"         # Augmented dataset output folder

# Create target directory if not exists
if not os.path.exists(target_dataset):
    os.makedirs(target_dataset)

def random_rotate(image, angle_range=(-10, 10)):
    """Rotate image by a random angle within given range."""
    h, w = image.shape[:2]
    angle = random.uniform(*angle_range)
    matrix = cv2.getRotationMatrix2D((w / 2, h / 2), angle, 1)
    rotated = cv2.warpAffine(image, matrix, (w, h), borderMode=cv2.BORDER_REFLECT)
    return rotated

def augment_and_save(image_path, save_dir, image_name):
    img = cv2.imread(image_path)
    if img is None:
        print(f"❌ Failed to load image: {image_path}")
        return False

    base, ext = os.path.splitext(image_name)

    # 1️⃣ Save Original Image
    orig_path = os.path.join(save_dir, f"{base}{ext}")
    cv2.imwrite(orig_path, img)

    # 2️⃣ Save Flipped Image
    flipped_img = cv2.flip(img, 1)
    flipped_name = f"{base}_flipped{ext}"
    flipped_path = os.path.join(save_dir, flipped_name)
    cv2.imwrite(flipped_path, flipped_img)

    # 3️⃣ Save Randomly Rotated Image
    rotated_img = random_rotate(img)
    rotated_name = f"{base}_rotated{ext}"
    rotated_path = os.path.join(save_dir, rotated_name)
    cv2.imwrite(rotated_path, rotated_img)

    # 4️⃣ Save Flipped + Rotated Image
    flipped_rotated_img = random_rotate(flipped_img)
    flipped_rotated_name = f"{base}_flipped_rotated{ext}"
    flipped_rotated_path = os.path.join(save_dir, flipped_rotated_name)
    cv2.imwrite(flipped_rotated_path, flipped_rotated_img)

    return True

# Walk through dataset
for split in ["train", "valid", "test"]:
    split_dir = os.path.join(source_dataset, split)
    target_split_dir = os.path.join(target_dataset, split)

    for class_name in os.listdir(split_dir):
        class_dir = os.path.join(split_dir, class_name)
        target_class_dir = os.path.join(target_split_dir, class_name)
        os.makedirs(target_class_dir, exist_ok=True)

        image_files = [f for f in os.listdir(class_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]
        print(f"\n🔄 Augmenting {split}/{class_name} ({len(image_files)} images)")

        for img_name in tqdm(image_files, desc=f"{split}/{class_name}"):
            src_img_path = os.path.join(class_dir, img_name)
            augment_and_save(src_img_path, target_class_dir, img_name)

print("\n✅ Augmentation complete. Full dataset saved to:")
print(target_dataset)
# Out:
# 🔄 Augmenting train/Beautiful (19 images)
# train/Beautiful: 100%|██████████| 19/19 [00:00<00:00, 249.31it/s]
# 🔄 Augmenting train/Come (15 images)
# train/Come: 100%|██████████| 15/15 [00:00<00:00, 245.66it/s]
# 🔄 Augmenting train/Drink (25 images)
# train/Drink: 100%|██████████| 25/25 [00:00<00:00, 322.64it/s]
# 🔄 Augmenting train/Eat (23 images)
# train/Eat: 100%|██████████| 23/23 [00:00<00:00, 334.90it/s]
# 🔄 Augmenting train/Fine_Okay (20 images)
# train/Fine_Okay: 100%|██████████| 20/20 [00:00<00:00, 321.78it/s]
# 🔄 Augmenting train/Friend (19 images)
# train/Friend: 100%|██████████| 19/19 [00:00<00:00, 313.57it/s]
# 🔄 Augmenting train/Go (20 images)
# train/Go: 100%|██████████| 20/20 [00:00<00:00, 324.94it/s]
# 🔄 Augmenting train/Good (18 images)
# train/Good: 100%|██████████| 18/18 [00:00<00:00, 320.73it/s]
# 🔄 Augmenting train/Happy (24 images)
# train/Happy: 100%|██████████| 24/24 [00:00<00:00, 281.25it/s]
# 🔄 Augmenting train/Hello_Hi (17 images)
# train/Hello_Hi: 100%|██████████| 17/17 [00:00<00:00, 276.78it/s]
# 🔄 Augmenting train/Help (17 images)
# train/Help: 100%|██████████| 17/17 [00:00<00:00, 232.97it/s]
# 🔄 Augmenting train/He_She_They (18 images)
# train/He_She_They: 100%|██████████| 18/18 [00:00<00:00, 303.31it/s]
# 🔄 Augmenting train/How (18 images)
# train/How: 100%|██████████| 18/18 [00:00<00:00, 309.83it/s]
# 🔄 Augmenting train/Hungry (19 images)
# train/Hungry: 100%|██████████| 19/19 [00:00<00:00, 299.12it/s]
# 🔄 Augmenting train/I_Me (17 images)
# train/I_Me: 100%|██████████| 17/17 [00:00<00:00, 298.70it/s]
# 🔄 Augmenting train/Like (23 images)
# train/Like: 100%|██████████| 23/23 [00:00<00:00, 275.99it/s]
# 🔄 Augmenting train/Love (22 images)
# train/Love: 100%|██████████| 22/22 [00:00<00:00, 189.96it/s]
# 🔄 Augmenting train/My_Mine (22 images)
# train/My_Mine: 100%|██████████| 22/22 [00:00<00:00, 282.39it/s]
# 🔄 Augmenting train/No (19 images)
# train/No: 100%|██████████| 19/19 [00:00<00:00, 290.91it/s]
# 🔄 Augmenting train/See_Look (20 images)
# train/See_Look: 100%|██████████| 20/20 [00:00<00:00, 293.38it/s]
# 🔄 Augmenting train/Sleep (20 images)
# train/Sleep: 100%|██████████| 20/20 [00:00<00:00, 257.78it/s]
# 🔄 Augmenting train/Sorry (22 images)
# train/Sorry: 100%|██████████| 22/22 [00:00<00:00, 271.42it/s]
# 🔄 Augmenting train/Thank_You (20 images)
# train/Thank_You: 100%|██████████| 20/20 [00:00<00:00, 295.16it/s]
# 🔄 Augmenting train/Want (19 images)
# train/Want: 100%|██████████| 19/19 [00:00<00:00, 269.79it/s]
# 🔄 Augmenting train/We_Us (26 images)
# train/We_Us: 100%|██████████| 26/26 [00:00<00:00, 277.82it/s]
# 🔄 Augmenting train/What (17 images)
# train/What: 100%|██████████| 17/17 [00:00<00:00, 287.05it/s]
# 🔄 Augmenting train/When (24 images)
# train/When: 100%|██████████| 24/24 [00:00<00:00, 280.63it/s]
# 🔄 Augmenting train/Where (18 images)
# train/Where: 100%|██████████| 18/18 [00:00<00:00, 264.50it/s]
# 🔄 Augmenting train/Yes (12 images)
# train/Yes: 100%|██████████| 12/12 [00:00<00:00, 253.38it/s]
# 🔄 Augmenting train/You_Your (22 images)
# train/You_Your: 100%|██████████| 22/22 [00:00<00:00, 275.21it/s]
# 🔄 Augmenting valid/Beautiful (4 images)
# valid/Beautiful: 100%|██████████| 4/4 [00:00<00:00, 288.94it/s]
# 🔄 Augmenting valid/Come (12 images)
# valid/Come: 100%|██████████| 12/12 [00:00<00:00, 246.79it/s]
# 🔄 Augmenting valid/Drink (4 images)
# valid/Drink: 100%|██████████| 4/4 [00:00<00:00, 264.62it/s]
# 🔄 Augmenting valid/Eat (4 images)
# valid/Eat: 100%|██████████| 4/4 [00:00<00:00, 270.38it/s]
# 🔄 Augmenting valid/Fine_Okay (5 images)
# valid/Fine_Okay: 100%|██████████| 5/5 [00:00<00:00, 261.46it/s]
# 🔄 Augmenting valid/Friend (9 images)
# valid/Friend: 100%|██████████| 9/9 [00:00<00:00, 237.56it/s]
# 🔄 Augmenting valid/Go (7 images)
# valid/Go: 100%|██████████| 7/7 [00:00<00:00, 235.95it/s]
# 🔄 Augmenting valid/Good (7 images)
# valid/Good: 100%|██████████| 7/7 [00:00<00:00, 266.70it/s]
# 🔄 Augmenting valid/Happy (5 images)
# valid/Happy: 100%|██████████| 5/5 [00:00<00:00, 291.75it/s]
# 🔄 Augmenting valid/Hello_Hi (5 images)
# valid/Hello_Hi: 100%|██████████| 5/5 [00:00<00:00, 292.22it/s]
# 🔄 Augmenting valid/Help (6 images)
# valid/Help: 100%|██████████| 6/6 [00:00<00:00, 256.12it/s]
# 🔄 Augmenting valid/He_She_They (4 images)
# valid/He_She_They: 100%|██████████| 4/4 [00:00<00:00, 287.62it/s]
# 🔄 Augmenting valid/How (5 images)
# valid/How: 100%|██████████| 5/5 [00:00<00:00, 259.56it/s]
# 🔄 Augmenting valid/Hungry (8 images)
# valid/Hungry: 100%|██████████| 8/8 [00:00<00:00, 264.49it/s]
# 🔄 Augmenting valid/I_Me (6 images)
# valid/I_Me: 100%|██████████| 6/6 [00:00<00:00, 270.54it/s]
# 🔄 Augmenting valid/Like (4 images)
# valid/Like: 100%|██████████| 4/4 [00:00<00:00, 153.09it/s]
# 🔄 Augmenting valid/Love (4 images)
# valid/Love: 100%|██████████| 4/4 [00:00<00:00, 223.80it/s]
# 🔄 Augmenting valid/My_Mine (5 images)
# valid/My_Mine: 100%|██████████| 5/5 [00:00<00:00, 220.77it/s]
# 🔄 Augmenting valid/No (6 images)
# valid/No: 100%|██████████| 6/6 [00:00<00:00, 231.82it/s]
# 🔄 Augmenting valid/See_Look (3 images)
# valid/See_Look: 100%|██████████| 3/3 [00:00<00:00, 154.96it/s]
# 🔄 Augmenting valid/Sleep (5 images)
# valid/Sleep: 100%|██████████| 5/5 [00:00<00:00, 198.35it/s]
# 🔄 Augmenting valid/Sorry (4 images)
# valid/Sorry: 100%|██████████| 4/4 [00:00<00:00, 162.07it/s]
# 🔄 Augmenting valid/Thank_You (10 images)
# valid/Thank_You: 100%|██████████| 10/10 [00:00<00:00, 215.41it/s]
# 🔄 Augmenting valid/Want (4 images)
# valid/Want: 100%|██████████| 4/4 [00:00<00:00, 254.13it/s]
# 🔄 Augmenting valid/We_Us (2 images)
# valid/We_Us: 100%|██████████| 2/2 [00:00<00:00, 222.56it/s]
# 🔄 Augmenting valid/What (7 images)
# valid/What: 100%|██████████| 7/7 [00:00<00:00, 225.82it/s]
# 🔄 Augmenting valid/When (4 images)
# valid/When: 100%|██████████| 4/4 [00:00<00:00, 228.01it/s]
# 🔄 Augmenting valid/Where (9 images)
# valid/Where: 100%|██████████| 9/9 [00:00<00:00, 233.47it/s]
# 🔄 Augmenting valid/Yes (8 images)
# valid/Yes: 100%|██████████| 8/8 [00:00<00:00, 201.33it/s]
# 🔄 Augmenting valid/You_Your (6 images)
# valid/You_Your: 100%|██████████| 6/6 [00:00<00:00, 248.73it/s]
# 🔄 Augmenting test/Beautiful (7 images)
# test/Beautiful: 100%|██████████| 7/7 [00:00<00:00, 237.25it/s]
# 🔄 Augmenting test/Come (2 images)
# test/Come: 100%|██████████| 2/2 [00:00<00:00, 283.37it/s]
# 🔄 Augmenting test/Drink (1 images)
# test/Drink: 100%|██████████| 1/1 [00:00<00:00, 198.58it/s]
# 🔄 Augmenting test/Eat (2 images)
# test/Eat: 100%|██████████| 2/2 [00:00<00:00, 208.53it/s]
# 🔄 Augmenting test/Fine_Okay (2 images)
# test/Fine_Okay: 100%|██████████| 2/2 [00:00<00:00, 220.51it/s]
# 🔄 Augmenting test/Friend (2 images)
# test/Friend: 100%|██████████| 2/2 [00:00<00:00, 288.14it/s]
# 🔄 Augmenting test/Go (2 images)
# test/Go: 100%|██████████| 2/2 [00:00<00:00, 248.44it/s]
# 🔄 Augmenting test/Good (2 images)
# test/Good: 100%|██████████| 2/2 [00:00<00:00, 228.77it/s]
# 🔄 Augmenting test/Happy (1 images)
# test/Happy: 100%|██████████| 1/1 [00:00<00:00, 260.86it/s]
# 🔄 Augmenting test/Hello_Hi (2 images)
# test/Hello_Hi: 100%|██████████| 2/2 [00:00<00:00, 248.46it/s]
# 🔄 Augmenting test/Help (4 images)
# test/Help: 100%|██████████| 4/4 [00:00<00:00, 227.20it/s]
# 🔄 Augmenting test/He_She_They (3 images)
# test/He_She_They: 100%|██████████| 3/3 [00:00<00:00, 212.50it/s]
# 🔄 Augmenting test/How (5 images)
# test/How: 100%|██████████| 5/5 [00:00<00:00, 244.20it/s]
# 🔄 Augmenting test/Hungry (3 images)
# test/Hungry: 100%|██████████| 3/3 [00:00<00:00, 246.18it/s]
# 🔄 Augmenting test/I_Me (3 images)
# test/I_Me: 100%|██████████| 3/3 [00:00<00:00, 274.38it/s]
# 🔄 Augmenting test/Like (3 images)
# test/Like: 100%|██████████| 3/3 [00:00<00:00, 235.22it/s]
# 🔄 Augmenting test/Love (4 images)
# test/Love: 100%|██████████| 4/4 [00:00<00:00, 143.97it/s]
# 🔄 Augmenting test/My_Mine (3 images)
# test/My_Mine: 100%|██████████| 3/3 [00:00<00:00, 252.49it/s]
# 🔄 Augmenting test/No (2 images)
# test/No: 100%|██████████| 2/2 [00:00<00:00, 27.35it/s]
# 🔄 Augmenting test/See_Look (4 images)
# test/See_Look: 100%|██████████| 4/4 [00:00<00:00, 53.47it/s]
# 🔄 Augmenting test/Sleep (3 images)
# test/Sleep: 100%|██████████| 3/3 [00:00<00:00, 49.30it/s]
# 🔄 Augmenting test/Sorry (2 images)
# test/Sorry: 100%|██████████| 2/2 [00:00<00:00, 35.70it/s]
# 🔄 Augmenting test/Want (4 images)
# test/Want: 100%|██████████| 4/4 [00:00<00:00, 260.88it/s]
# 🔄 Augmenting test/We_Us (1 images)
# test/We_Us: 100%|██████████| 1/1 [00:00<00:00, 17.49it/s]
# 🔄 Augmenting test/What (2 images)
# test/What: 100%|██████████| 2/2 [00:00<00:00, 29.10it/s]
# 🔄 Augmenting test/When (2 images)
# test/When: 100%|██████████| 2/2 [00:00<00:00, 30.59it/s]
# 🔄 Augmenting test/Where (3 images)
# test/Where: 100%|██████████| 3/3 [00:00<00:00, 43.87it/s]
# 🔄 Augmenting test/Yes (6 images)
# test/Yes: 100%|██████████| 6/6 [00:00<00:00, 40.13it/s]
# 🔄 Augmenting test/You_Your (1 images)
# test/You_Your: 100%|██████████| 1/1 [00:00<00:00, 16.20it/s]
# ✅ Augmentation complete. Full dataset saved to:
# E:\New folder\isl_inverted

# %%
import os
import cv2
import random
from tqdm import tqdm

# Paths
source_dataset = r"E:\New folder\images for phrases_split"  # Your cropped dataset
target_dataset = r"E:\New folder\images_inverted"         # Augmented dataset output folder

# Create target directory if not exists
if not os.path.exists(target_dataset):
    os.makedirs(target_dataset)

def random_rotate(image, angle_range=(-10, 10)):
    """Rotate image by a random angle within given range."""
    h, w = image.shape[:2]
    angle = random.uniform(*angle_range)
    matrix = cv2.getRotationMatrix2D((w / 2, h / 2), angle, 1)
    rotated = cv2.warpAffine(image, matrix, (w, h), borderMode=cv2.BORDER_REFLECT)
    return rotated

def augment_and_save(image_path, save_dir, image_name):
    img = cv2.imread(image_path)
    if img is None:
        print(f"❌ Failed to load image: {image_path}")
        return False

    base, ext = os.path.splitext(image_name)

    # 1️⃣ Save Original Image
    orig_path = os.path.join(save_dir, f"{base}{ext}")
    cv2.imwrite(orig_path, img)

    # 2️⃣ Save Flipped Image
    flipped_img = cv2.flip(img, 1)
    flipped_name = f"{base}_flipped{ext}"
    flipped_path = os.path.join(save_dir, flipped_name)
    cv2.imwrite(flipped_path, flipped_img)

    # 3️⃣ Save Randomly Rotated Image
    rotated_img = random_rotate(img)
    rotated_name = f"{base}_rotated{ext}"
    rotated_path = os.path.join(save_dir, rotated_name)
    cv2.imwrite(rotated_path, rotated_img)

    # 4️⃣ Save Flipped + Rotated Image
    flipped_rotated_img = random_rotate(flipped_img)
    flipped_rotated_name = f"{base}_flipped_rotated{ext}"
    flipped_rotated_path = os.path.join(save_dir, flipped_rotated_name)
    cv2.imwrite(flipped_rotated_path, flipped_rotated_img)

    return True

# Walk through dataset
for split in ["train", "valid", "test"]:
    split_dir = os.path.join(source_dataset, split)
    target_split_dir = os.path.join(target_dataset, split)

    for class_name in os.listdir(split_dir):
        class_dir = os.path.join(split_dir, class_name)
        target_class_dir = os.path.join(target_split_dir, class_name)
        os.makedirs(target_class_dir, exist_ok=True)

        image_files = [f for f in os.listdir(class_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]
        print(f"\n🔄 Augmenting {split}/{class_name} ({len(image_files)} images)")

        for img_name in tqdm(image_files, desc=f"{split}/{class_name}"):
            src_img_path = os.path.join(class_dir, img_name)
            augment_and_save(src_img_path, target_class_dir, img_name)

print("\n✅ Augmentation complete. Full dataset saved to:")
print(target_dataset)
# Out:
# 🔄 Augmenting train/again (28 images)
# train/again: 100%|██████████| 28/28 [00:01<00:00, 19.85it/s]
# 🔄 Augmenting train/agree (28 images)
# train/agree: 100%|██████████| 28/28 [00:01<00:00, 15.27it/s]
# 🔄 Augmenting train/answer (28 images)
# train/answer: 100%|██████████| 28/28 [00:01<00:00, 19.72it/s]
# 🔄 Augmenting train/attendance (28 images)
# train/attendance: 100%|██████████| 28/28 [00:01<00:00, 18.04it/s]
# 🔄 Augmenting train/book (28 images)
# train/book: 100%|██████████| 28/28 [00:01<00:00, 19.80it/s]
# 🔄 Augmenting train/break (28 images)
# train/break: 100%|██████████| 28/28 [00:01<00:00, 18.92it/s]
# 🔄 Augmenting train/careful (28 images)
# train/careful: 100%|██████████| 28/28 [00:01<00:00, 15.87it/s]
# 🔄 Augmenting train/change (28 images)
# train/change: 100%|██████████| 28/28 [00:01<00:00, 18.29it/s]
# 🔄 Augmenting train/chat (28 images)
# train/chat: 100%|██████████| 28/28 [00:01<00:00, 15.40it/s]
# 🔄 Augmenting train/congratulations (28 images)
# train/congratulations: 100%|██████████| 28/28 [00:01<00:00, 18.77it/s]
# 🔄 Augmenting train/email (28 images)
# train/email: 100%|██████████| 28/28 [00:01<00:00, 20.21it/s]
# 🔄 Augmenting train/file (28 images)
# train/file: 100%|██████████| 28/28 [00:01<00:00, 19.91it/s]
# 🔄 Augmenting train/good morning (28 images)
# train/good morning: 100%|██████████| 28/28 [00:01<00:00, 16.81it/s]
# 🔄 Augmenting train/happy birthday (28 images)
# train/happy birthday: 100%|██████████| 28/28 [00:01<00:00, 17.43it/s]
# 🔄 Augmenting train/home (28 images)
# train/home: 100%|██████████| 28/28 [00:01<00:00, 16.89it/s]
# 🔄 Augmenting train/how are you (28 images)
# train/how are you: 100%|██████████| 28/28 [00:01<00:00, 18.99it/s]
# 🔄 Augmenting train/hungry (28 images)
# train/hungry: 100%|██████████| 28/28 [00:01<00:00, 15.50it/s]
# 🔄 Augmenting train/i need help (28 images)
# train/i need help: 100%|██████████| 28/28 [00:01<00:00, 14.53it/s]
# 🔄 Augmenting train/join (28 images)
# train/join: 100%|██████████| 28/28 [00:01<00:00, 15.78it/s]
# 🔄 Augmenting train/keepsmile (28 images)
# train/keepsmile: 100%|██████████| 28/28 [00:01<00:00, 19.47it/s]
# 🔄 Augmenting train/meet (28 images)
# train/meet: 100%|██████████| 28/28 [00:01<00:00, 19.09it/s]
# 🔄 Augmenting train/mistake (28 images)
# train/mistake: 100%|██████████| 28/28 [00:01<00:00, 17.93it/s]
# 🔄 Augmenting train/open (28 images)
# train/open: 100%|██████████| 28/28 [00:01<00:00, 15.48it/s]
# 🔄 Augmenting train/opinion (28 images)
# train/opinion: 100%|██████████| 28/28 [00:01<00:00, 19.98it/s]
# 🔄 Augmenting train/pass (28 images)
# train/pass: 100%|██████████| 28/28 [00:01<00:00, 17.75it/s]
# 🔄 Augmenting train/please (28 images)
# train/please: 100%|██████████| 28/28 [00:01<00:00, 19.28it/s]
# 🔄 Augmenting train/practice (28 images)
# train/practice: 100%|██████████| 28/28 [00:01<00:00, 19.30it/s]
# 🔄 Augmenting train/pressure (28 images)
# train/pressure: 100%|██████████| 28/28 [00:01<00:00, 20.04it/s]
# 🔄 Augmenting train/problem (28 images)
# train/problem: 100%|██████████| 28/28 [00:01<00:00, 16.11it/s]
# 🔄 Augmenting train/questions (28 images)
# train/questions: 100%|██████████| 28/28 [00:01<00:00, 20.78it/s]
# 🔄 Augmenting train/remember (28 images)
# train/remember: 100%|██████████| 28/28 [00:01<00:00, 19.30it/s]
# 🔄 Augmenting train/seat (28 images)
# train/seat: 100%|██████████| 28/28 [00:01<00:00, 20.36it/s]
# 🔄 Augmenting train/shift (28 images)
# train/shift: 100%|██████████| 28/28 [00:01<00:00, 16.31it/s]
# 🔄 Augmenting train/sick (28 images)
# train/sick: 100%|██████████| 28/28 [00:01<00:00, 20.32it/s]
# 🔄 Augmenting train/stop (28 images)
# train/stop: 100%|██████████| 28/28 [00:01<00:00, 16.24it/s]
# 🔄 Augmenting train/sun (28 images)
# train/sun: 100%|██████████| 28/28 [00:01<00:00, 15.37it/s]
# 🔄 Augmenting train/team (28 images)
# train/team: 100%|██████████| 28/28 [00:01<00:00, 20.90it/s]
# 🔄 Augmenting train/test (0 images)
# train/test: 0it [00:00, ?it/s]
# 🔄 Augmenting train/thirsty (28 images)
# train/thirsty: 100%|██████████| 28/28 [00:01<00:00, 16.13it/s]
# 🔄 Augmenting train/this (28 images)
# train/this: 100%|██████████| 28/28 [00:01<00:00, 21.33it/s]
# 🔄 Augmenting train/together (28 images)
# train/together: 100%|██████████| 28/28 [00:01<00:00, 16.67it/s]
# 🔄 Augmenting train/train (0 images)
# train/train: 0it [00:00, ?it/s]
# 🔄 Augmenting train/understand (28 images)
# train/understand: 100%|██████████| 28/28 [00:01<00:00, 16.36it/s]
# 🔄 Augmenting train/valid (0 images)
# train/valid: 0it [00:00, ?it/s]
# 🔄 Augmenting train/wait (28 images)
# train/wait: 100%|██████████| 28/28 [00:01<00:00, 15.99it/s]
# 🔄 Augmenting train/where (28 images)
# train/where: 100%|██████████| 28/28 [00:01<00:00, 16.80it/s]
# 🔄 Augmenting train/write (28 images)
# train/write: 100%|██████████| 28/28 [00:01<00:00, 15.13it/s]
# 🔄 Augmenting valid/again (6 images)
# valid/again: 100%|██████████| 6/6 [00:00<00:00, 18.03it/s]
# 🔄 Augmenting valid/agree (6 images)
# valid/agree: 100%|██████████| 6/6 [00:00<00:00, 13.98it/s]
# 🔄 Augmenting valid/answer (6 images)
# valid/answer: 100%|██████████| 6/6 [00:00<00:00, 18.44it/s]
# 🔄 Augmenting valid/attendance (6 images)
# valid/attendance: 100%|██████████| 6/6 [00:00<00:00, 19.29it/s]
# 🔄 Augmenting valid/book (6 images)
# valid/book: 100%|██████████| 6/6 [00:00<00:00, 20.83it/s]
# 🔄 Augmenting valid/break (6 images)
# valid/break: 100%|██████████| 6/6 [00:00<00:00, 18.31it/s]
# 🔄 Augmenting valid/careful (6 images)
# valid/careful: 100%|██████████| 6/6 [00:00<00:00, 16.23it/s]
# 🔄 Augmenting valid/change (6 images)
# valid/change: 100%|██████████| 6/6 [00:00<00:00, 19.90it/s]
# 🔄 Augmenting valid/chat (6 images)
# valid/chat: 100%|██████████| 6/6 [00:00<00:00, 16.08it/s]
# 🔄 Augmenting valid/congratulations (6 images)
# valid/congratulations: 100%|██████████| 6/6 [00:00<00:00,  9.19it/s]
# 🔄 Augmenting valid/email (6 images)
# valid/email: 100%|██████████| 6/6 [00:00<00:00, 20.85it/s]
# 🔄 Augmenting valid/file (6 images)
# valid/file: 100%|██████████| 6/6 [00:00<00:00, 20.23it/s]
# 🔄 Augmenting valid/good morning (6 images)
# valid/good morning: 100%|██████████| 6/6 [00:00<00:00, 17.59it/s]
# 🔄 Augmenting valid/happy birthday (6 images)
# valid/happy birthday: 100%|██████████| 6/6 [00:00<00:00, 15.10it/s]
# 🔄 Augmenting valid/home (6 images)
# valid/home: 100%|██████████| 6/6 [00:00<00:00, 17.47it/s]
# 🔄 Augmenting valid/how are you (6 images)
# valid/how are you: 100%|██████████| 6/6 [00:00<00:00, 17.12it/s]
# 🔄 Augmenting valid/hungry (6 images)
# valid/hungry: 100%|██████████| 6/6 [00:00<00:00, 13.64it/s]
# 🔄 Augmenting valid/i need help (6 images)
# valid/i need help: 100%|██████████| 6/6 [00:00<00:00, 16.17it/s]
# 🔄 Augmenting valid/join (6 images)
# valid/join: 100%|██████████| 6/6 [00:00<00:00, 13.27it/s]
# 🔄 Augmenting valid/keepsmile (6 images)
# valid/keepsmile: 100%|██████████| 6/6 [00:00<00:00, 17.44it/s]
# 🔄 Augmenting valid/meet (6 images)
# valid/meet: 100%|██████████| 6/6 [00:00<00:00, 17.16it/s]
# 🔄 Augmenting valid/mistake (6 images)
# valid/mistake: 100%|██████████| 6/6 [00:00<00:00, 18.87it/s]
# 🔄 Augmenting valid/open (6 images)
# valid/open: 100%|██████████| 6/6 [00:00<00:00, 14.31it/s]
# 🔄 Augmenting valid/opinion (6 images)
# valid/opinion: 100%|██████████| 6/6 [00:00<00:00, 15.48it/s]
# 🔄 Augmenting valid/pass (6 images)
# valid/pass: 100%|██████████| 6/6 [00:00<00:00, 11.83it/s]
# 🔄 Augmenting valid/please (6 images)
# valid/please: 100%|██████████| 6/6 [00:00<00:00, 20.79it/s]
# 🔄 Augmenting valid/practice (6 images)
# valid/practice: 100%|██████████| 6/6 [00:00<00:00, 20.13it/s]
# 🔄 Augmenting valid/pressure (6 images)
# valid/pressure: 100%|██████████| 6/6 [00:00<00:00, 20.78it/s]
# 🔄 Augmenting valid/problem (6 images)
# valid/problem: 100%|██████████| 6/6 [00:00<00:00, 20.27it/s]
# 🔄 Augmenting valid/questions (6 images)
# valid/questions: 100%|██████████| 6/6 [00:00<00:00, 20.25it/s]
# 🔄 Augmenting valid/remember (6 images)
# valid/remember: 100%|██████████| 6/6 [00:00<00:00, 20.25it/s]
# 🔄 Augmenting valid/seat (6 images)
# valid/seat: 100%|██████████| 6/6 [00:00<00:00, 20.69it/s]
# 🔄 Augmenting valid/shift (6 images)
# valid/shift: 100%|██████████| 6/6 [00:00<00:00, 19.41it/s]
# 🔄 Augmenting valid/sick (6 images)
# valid/sick: 100%|██████████| 6/6 [00:00<00:00, 21.25it/s]
# 🔄 Augmenting valid/stop (6 images)
# valid/stop: 100%|██████████| 6/6 [00:00<00:00, 14.81it/s]
# 🔄 Augmenting valid/sun (6 images)
# valid/sun: 100%|██████████| 6/6 [00:00<00:00, 18.90it/s]
# 🔄 Augmenting valid/team (6 images)
# valid/team: 100%|██████████| 6/6 [00:00<00:00, 20.10it/s]
# 🔄 Augmenting valid/test (0 images)
# valid/test: 0it [00:00, ?it/s]
# 🔄 Augmenting valid/thirsty (6 images)
# valid/thirsty: 100%|██████████| 6/6 [00:00<00:00, 15.33it/s]
# 🔄 Augmenting valid/this (6 images)
# valid/this: 100%|██████████| 6/6 [00:00<00:00, 21.12it/s]
# 🔄 Augmenting valid/together (6 images)
# valid/together: 100%|██████████| 6/6 [00:00<00:00, 20.47it/s]
# 🔄 Augmenting valid/train (0 images)
# valid/train: 0it [00:00, ?it/s]
# 🔄 Augmenting valid/understand (6 images)
# valid/understand: 100%|██████████| 6/6 [00:00<00:00,  9.76it/s]
# 🔄 Augmenting valid/valid (0 images)
# valid/valid: 0it [00:00, ?it/s]
# 🔄 Augmenting valid/wait (6 images)
# valid/wait: 100%|██████████| 6/6 [00:00<00:00, 15.80it/s]
# 🔄 Augmenting valid/where (6 images)
# valid/where: 100%|██████████| 6/6 [00:00<00:00, 20.58it/s]
# 🔄 Augmenting valid/write (6 images)
# valid/write: 100%|██████████| 6/6 [00:00<00:00, 16.18it/s]
# 🔄 Augmenting test/again (6 images)
# test/again: 100%|██████████| 6/6 [00:00<00:00, 20.91it/s]
# 🔄 Augmenting test/agree (6 images)
# test/agree: 100%|██████████| 6/6 [00:00<00:00, 15.58it/s]
# 🔄 Augmenting test/answer (6 images)
# test/answer: 100%|██████████| 6/6 [00:00<00:00, 19.51it/s]
# 🔄 Augmenting test/attendance (6 images)
# test/attendance: 100%|██████████| 6/6 [00:00<00:00, 19.50it/s]
# 🔄 Augmenting test/book (6 images)
# test/book: 100%|██████████| 6/6 [00:00<00:00, 20.08it/s]
# 🔄 Augmenting test/break (6 images)
# test/break: 100%|██████████| 6/6 [00:00<00:00, 18.70it/s]
# 🔄 Augmenting test/careful (6 images)
# test/careful: 100%|██████████| 6/6 [00:00<00:00, 15.89it/s]
# 🔄 Augmenting test/change (6 images)
# test/change: 100%|██████████| 6/6 [00:00<00:00, 19.70it/s]
# 🔄 Augmenting test/chat (6 images)
# test/chat: 100%|██████████| 6/6 [00:00<00:00, 15.02it/s]
# 🔄 Augmenting test/congratulations (6 images)
# test/congratulations: 100%|██████████| 6/6 [00:00<00:00, 17.00it/s]
# 🔄 Augmenting test/email (6 images)
# test/email: 100%|██████████| 6/6 [00:00<00:00, 19.75it/s]
# 🔄 Augmenting test/file (6 images)
# test/file: 100%|██████████| 6/6 [00:00<00:00, 19.37it/s]
# 🔄 Augmenting test/good morning (6 images)
# test/good morning: 100%|██████████| 6/6 [00:00<00:00,  8.21it/s]
# 🔄 Augmenting test/happy birthday (6 images)
# test/happy birthday: 100%|██████████| 6/6 [00:00<00:00, 18.48it/s]
# 🔄 Augmenting test/home (6 images)
# test/home: 100%|██████████| 6/6 [00:00<00:00, 18.93it/s]
# 🔄 Augmenting test/how are you (6 images)
# test/how are you: 100%|██████████| 6/6 [00:00<00:00, 20.49it/s]
# 🔄 Augmenting test/hungry (6 images)
# test/hungry: 100%|██████████| 6/6 [00:00<00:00, 16.00it/s]
# 🔄 Augmenting test/i need help (6 images)
# test/i need help: 100%|██████████| 6/6 [00:00<00:00, 18.73it/s]
# 🔄 Augmenting test/join (6 images)
# test/join: 100%|██████████| 6/6 [00:00<00:00, 16.40it/s]
# 🔄 Augmenting test/keepsmile (6 images)
# test/keepsmile: 100%|██████████| 6/6 [00:00<00:00, 19.65it/s]
# 🔄 Augmenting test/meet (6 images)
# test/meet: 100%|██████████| 6/6 [00:00<00:00, 18.22it/s]
# 🔄 Augmenting test/mistake (6 images)
# test/mistake: 100%|██████████| 6/6 [00:00<00:00, 21.10it/s]
# 🔄 Augmenting test/open (6 images)
# test/open: 100%|██████████| 6/6 [00:00<00:00, 15.71it/s]
# 🔄 Augmenting test/opinion (6 images)
# test/opinion: 100%|██████████| 6/6 [00:00<00:00, 20.10it/s]
# 🔄 Augmenting test/pass (6 images)
# test/pass: 100%|██████████| 6/6 [00:00<00:00, 20.55it/s]
# 🔄 Augmenting test/please (6 images)
# test/please: 100%|██████████| 6/6 [00:00<00:00, 20.67it/s]
# 🔄 Augmenting test/practice (6 images)
# test/practice: 100%|██████████| 6/6 [00:00<00:00, 18.01it/s]
# 🔄 Augmenting test/pressure (6 images)
# test/pressure: 100%|██████████| 6/6 [00:00<00:00, 19.78it/s]
# 🔄 Augmenting test/problem (6 images)
# test/problem: 100%|██████████| 6/6 [00:00<00:00, 16.76it/s]
# 🔄 Augmenting test/questions (6 images)
# test/questions: 100%|██████████| 6/6 [00:00<00:00, 13.17it/s]
# 🔄 Augmenting test/remember (6 images)
# test/remember: 100%|██████████| 6/6 [00:00<00:00, 20.32it/s]
# 🔄 Augmenting test/seat (6 images)
# test/seat: 100%|██████████| 6/6 [00:00<00:00, 21.28it/s]
# 🔄 Augmenting test/shift (6 images)
# test/shift: 100%|██████████| 6/6 [00:00<00:00, 20.45it/s]
# 🔄 Augmenting test/sick (6 images)
# test/sick: 100%|██████████| 6/6 [00:00<00:00, 20.60it/s]
# 🔄 Augmenting test/stop (6 images)
# test/stop: 100%|██████████| 6/6 [00:00<00:00, 15.38it/s]
# 🔄 Augmenting test/sun (6 images)
# test/sun: 100%|██████████| 6/6 [00:00<00:00, 19.45it/s]
# 🔄 Augmenting test/team (6 images)
# test/team: 100%|██████████| 6/6 [00:00<00:00, 16.93it/s]
# 🔄 Augmenting test/test (0 images)
# test/test: 0it [00:00, ?it/s]
# 🔄 Augmenting test/thirsty (6 images)
# test/thirsty: 100%|██████████| 6/6 [00:00<00:00, 16.01it/s]
# 🔄 Augmenting test/this (6 images)
# test/this: 100%|██████████| 6/6 [00:00<00:00, 20.79it/s]
# 🔄 Augmenting test/together (6 images)
# test/together: 100%|██████████| 6/6 [00:00<00:00, 19.78it/s]
# 🔄 Augmenting test/train (0 images)
# test/train: 0it [00:00, ?it/s]
# 🔄 Augmenting test/understand (6 images)
# test/understand: 100%|██████████| 6/6 [00:00<00:00, 16.33it/s]
# 🔄 Augmenting test/valid (0 images)
# test/valid: 0it [00:00, ?it/s]
# 🔄 Augmenting test/wait (6 images)
# test/wait: 100%|██████████| 6/6 [00:00<00:00, 16.01it/s]
# 🔄 Augmenting test/where (6 images)
# test/where: 100%|██████████| 6/6 [00:00<00:00, 20.47it/s]
# 🔄 Augmenting test/write (6 images)
# test/write: 100%|██████████| 6/6 [00:00<00:00, 16.05it/s]
# ✅ Augmentation complete. Full dataset saved to:
# E:\New folder\images_inverted
